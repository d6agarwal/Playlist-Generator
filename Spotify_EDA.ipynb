# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv('data/data_moods.csv')

# %% [markdown]
# Display Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              686 non-null    object
#  1   album             686 non-null    object
#  2   artist            686 non-null    object
#  3   id                686 non-null    object
#  4   release_date      686 non-null    object
#  5   popularity        686 non-null    int64
#  6   length            686 non-null    int64
#  7   danceability      686 non-null    float64
#  8   acousticness      686 non-null    float64
#  9   energy            686 non-null    float64
#  10  instrumentalness  686 non-null    float64
#  11  liveness          686 non-null    float64
#  12  valence           686 non-null    float64
#  13  loudness          686 non-null    float64
#  14  speechiness       686 non-null    float64
#  15  tempo             686 non-null    float64
# ...

# %% [markdown]
# Showing Columns

# %%
df.columns
# Out:
# Index(['name', 'album', 'artist', 'id', 'release_date', 'popularity', 'length',
#        'danceability', 'acousticness', 'energy', 'instrumentalness',
#        'liveness', 'valence', 'loudness', 'speechiness', 'tempo', 'key',
#        'time_signature', 'mood'],
#       dtype='object')

# %% [markdown]
# Correlations

# %%
df.corr(numeric_only = True)
# Out:
#                   popularity    length  danceability  acousticness    energy  \
# popularity          1.000000 -0.086197      0.134086     -0.039792  0.056923
# length             -0.086197  1.000000     -0.041378     -0.165689  0.116968
# danceability        0.134086 -0.041378      1.000000     -0.324908  0.332579
# acousticness       -0.039792 -0.165689     -0.324908      1.000000 -0.902001
# energy              0.056923  0.116968      0.332579     -0.902001  1.000000
# instrumentalness   -0.125816 -0.165860     -0.292267      0.578946 -0.591110
# liveness            0.034065 -0.044103      0.105590     -0.289672  0.341227
# valence             0.054375  0.003923      0.526196     -0.495770  0.528810
# loudness            0.100066  0.182840      0.350843     -0.790299  0.854015
# speechiness         0.056608 -0.060854      0.115579     -0.285138  0.342475
# tempo               0.016300  0.007995     -0.031581     -0.285407  0.318882
# ...

# %% [markdown]
# Plots

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(numeric_only = True), annot= True, fmt='.2f')
# Out:
# <Axes: >

# %%
df.hist(figsize=(20,20))
plt.title('Histogram plot', size = 15, weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Histogram plot')

# %%
sns.jointplot(x='energy',y='loudness',data=df,kind='scatter')
plt.show()

# %%
sns.jointplot(x='energy',y='loudness',data=df,kind='hex')
plt.show()

# %%
sns.jointplot(x='energy', y='loudness', data = df, kind = 'reg')
plt.show()

# %%
sns.jointplot(x='energy', y='loudness', data = df, kind = 'kde')
plt.show()

# %%
g = sns.jointplot(data=df, x="energy", y="loudness")
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6)
g.plot_marginals(sns.rugplot, color="r", height=-.15, clip_on=False)

# %%
fig=plt.figure(figsize=(10,10))
sns.regplot(data=df,x='energy',y='loudness')
# Out:
# <Axes: xlabel='energy', ylabel='loudness'>

# %%
df
# Out:
#                                             name  \
# 0                                           1999
# 1                                             23
# 2                                       9 Crimes
# 3                                 99 Luftballons
# 4    A Boy Brushed Red Living In Black And White
# ..                                           ...
# 681                                  windcatcher
# 682              yellow is the color of her eyes
# 683                           you broke me first
# 684                          you were good to me
# 685                                         æfre
#
#                                album          artist                      id  \
# 0                               1999          Prince  2H7PHVdQ3mXqEHXcvclTB0
# 1                                 23  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP
# 2                                  9     Damien Rice  5GZEeowhvSieFDiR8fQ2im
# ...

# %%
df['Count'] = 1
df_artist = df.groupby('artist')['Count'].sum().reset_index().sort_values(by='Count', ascending = False)
df_artist.head(10)
# Out:
#                   artist  Count
# 517      Various Artists      9
# 527        Wilson Trouvé      6
# 337         Nicky Romero      5
# 212           Hoobastank      4
# 372               Prince      4
# 277          Linkin Park      4
# 140            Disturbed      4
# 331  My Chemical Romance      4
# 480         The National      3
# 218          Isaac Elton      3

# %%
fig = px.bar(df_artist.head(10),x='artist', y='Count',text_auto=True)
fig.update_layout(legend_orientation="h",
                  legend=dict(x=0, y=1, traceorder='normal'),
                  title="Top 10 Artist",
                  margin=dict(l=0, r=0, t=30, b=0))
fig.show()

# %%
fig=px.pie(df_artist.head(10),values='Count',names='artist',hole=0.4)
fig.update_layout(title='Top 10 Artist',font_size=15,title_x=0.45,annotations=[dict(text='Artist',font_size=25, showarrow=False,height=800,width=700)])
fig.update_traces(textfont_size=15,textinfo='percent')
fig.show()

# %%
df_top_tracks=df.sort_values(by='popularity',ascending=False).head(10).reset_index(drop=True)
df_top_tracks.index=df_top_tracks.index + 1
df_top_tracks
# Out:
#                      name                                              album  \
# 1    lovely (with Khalid)                               lovely (with Khalid)
# 2                 Falling                                          Fine Line
# 3      you broke me first                                 you broke me first
# 4   when the party's over           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 5           Before You Go  Divinely Uninspired To A Hellish Extent (Exten...
# 6               All of Me              Love In The Future (Expanded Edition)
# 7         Pumped Up Kicks                                            Torches
# 8                  Africa                                            Toto IV
# 9              Take on Me                               Hunting High and Low
# 10              Surrender                                          Surrender
#
#                artist                      id release_date  popularity  \
# ...

# %%
df.drop(columns=['id', 'release_date', 'album']).set_index('name')
# Out:
#                                                      artist  popularity  \
# name
# 1999                                                 Prince          68
# 23                                           Blonde Redhead          43
# 9 Crimes                                        Damien Rice          60
# 99 Luftballons                                         Nena           2
# A Boy Brushed Red Living In Black And White       Underoath          60
# ...                                                     ...         ...
# windcatcher                                       Leo Nocta          36
# yellow is the color of her eyes                Soccer Mommy           5
# you broke me first                               Tate McRae          87
# you were good to me                           Jeremy Zucker          76
# æfre                                                  praam          41
#
#                                              length  danceability  \
# name
# ...
