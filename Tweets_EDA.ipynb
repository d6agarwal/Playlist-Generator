# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Dhruv
# [nltk_data]     Agarwal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Load tweet_emotions data set.

# %%
df = pd.read_csv("tweet_emotions.csv")

# %% [markdown]
# Print data frame.

# %%
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 3 columns]

# %% [markdown]
# Print the first five columns.

# %%
df.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %% [markdown]
# Print all of the columns of the data frame.

# %%
df.columns
# Out:
# Index(['tweet_id', 'sentiment', 'content'], dtype='object')

# %% [markdown]
# Print the number of sentiment words.

# %%
temp = df.groupby('sentiment').count()['content'].reset_index().sort_values(by='content',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_3ce58_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_3ce58_row1_col1 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_3ce58_row2_col1 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_3ce58_row3_col1 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_3ce58_row4_col1 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_3ce58_row5_col1 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_3ce58_row6_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_3ce58_row7_col1 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_3ce58_row8_col1 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_3ce58_row9_col1 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_3ce58_row10_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_3ce58_row11_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_3ce58_row12_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_3ce58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ce58_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_3ce58_level0_col1" class="col_heading level0 col1" >content</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ce58_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_3ce58_row0_col0" class="data row0 col0" >neutral</td>
#       <td id="T_3ce58_row0_col1" class="data row0 col1" >8638</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_3ce58_row1_col0" class="data row1 col0" >worry</td>
#       <td id="T_3ce58_row1_col1" class="data row1 col1" >8459</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_3ce58_row2_col0" class="data row2 col0" >happiness</td>
#       <td id="T_3ce58_row2_col1" class="data row2 col1" >5209</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_3ce58_row3_col0" class="data row3 col0" >sadness</td>
#       <td id="T_3ce58_row3_col1" class="data row3 col1" >5165</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_3ce58_row4_col0" class="data row4 col0" >love</td>
#       <td id="T_3ce58_row4_col1" class="data row4 col1" >3842</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_3ce58_row5_col0" class="data row5 col0" >surprise</td>
#       <td id="T_3ce58_row5_col1" class="data row5 col1" >2187</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_3ce58_row6_col0" class="data row6 col0" >fun</td>
#       <td id="T_3ce58_row6_col1" class="data row6 col1" >1776</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_3ce58_row7_col0" class="data row7 col0" >relief</td>
#       <td id="T_3ce58_row7_col1" class="data row7 col1" >1526</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_3ce58_row8_col0" class="data row8 col0" >hate</td>
#       <td id="T_3ce58_row8_col1" class="data row8 col1" >1323</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_3ce58_row9_col0" class="data row9 col0" >empty</td>
#       <td id="T_3ce58_row9_col1" class="data row9 col1" >827</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row10" class="row_heading level0 row10" >3</th>
#       <td id="T_3ce58_row10_col0" class="data row10 col0" >enthusiasm</td>
#       <td id="T_3ce58_row10_col1" class="data row10 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_3ce58_row11_col0" class="data row11 col0" >boredom</td>
#       <td id="T_3ce58_row11_col1" class="data row11 col1" >179</td>
#     </tr>
#     <tr>
#       <th id="T_3ce58_level0_row12" class="row_heading level0 row12" >0</th>
#       <td id="T_3ce58_row12_col0" class="data row12 col0" >anger</td>
#       <td id="T_3ce58_row12_col1" class="data row12 col1" >110</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Print data above as a bar graph.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %% [markdown]
# Print common words.

# %%
df['temp_list'] = df['content'].apply(lambda x:str(x).split())
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['content','temp_list']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b0550_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b0550_row1_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_b0550_row2_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_b0550_row3_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_b0550_row4_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_b0550_row5_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_b0550_row6_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_b0550_row7_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_b0550_row8_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_b0550_row9_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_b0550_row10_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_b0550_row11_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b0550_row12_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b0550_row13_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b0550_row14_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b0550_row15_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_b0550_row16_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_b0550_row17_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b0550_row18_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b0550_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b0550">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0550_level0_col0" class="col_heading level0 col0" >content</th>
#       <th id="T_b0550_level0_col1" class="col_heading level0 col1" >temp_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0550_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0550_row0_col0" class="data row0 col0" >to</td>
#       <td id="T_b0550_row0_col1" class="data row0 col1" >14039</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0550_row1_col0" class="data row1 col0" >I</td>
#       <td id="T_b0550_row1_col1" class="data row1 col1" >12635</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b0550_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_b0550_row2_col1" class="data row2 col1" >12052</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b0550_row3_col0" class="data row3 col0" >a</td>
#       <td id="T_b0550_row3_col1" class="data row3 col1" >9352</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b0550_row4_col0" class="data row4 col0" >my</td>
#       <td id="T_b0550_row4_col1" class="data row4 col1" >7160</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b0550_row5_col0" class="data row5 col0" >and</td>
#       <td id="T_b0550_row5_col1" class="data row5 col1" >6750</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b0550_row6_col0" class="data row6 col0" >i</td>
#       <td id="T_b0550_row6_col1" class="data row6 col1" >6257</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b0550_row7_col0" class="data row7 col0" >you</td>
#       <td id="T_b0550_row7_col1" class="data row7 col1" >5535</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b0550_row8_col0" class="data row8 col0" >is</td>
#       <td id="T_b0550_row8_col1" class="data row8 col1" >5254</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b0550_row9_col0" class="data row9 col0" >for</td>
#       <td id="T_b0550_row9_col1" class="data row9 col1" >5146</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b0550_row10_col0" class="data row10 col0" >in</td>
#       <td id="T_b0550_row10_col1" class="data row10 col1" >5053</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b0550_row11_col0" class="data row11 col0" >of</td>
#       <td id="T_b0550_row11_col1" class="data row11 col1" >4419</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b0550_row12_col0" class="data row12 col0" >it</td>
#       <td id="T_b0550_row12_col1" class="data row12 col1" >4333</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b0550_row13_col0" class="data row13 col0" >on</td>
#       <td id="T_b0550_row13_col1" class="data row13 col1" >3828</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b0550_row14_col0" class="data row14 col0" >have</td>
#       <td id="T_b0550_row14_col1" class="data row14 col1" >3430</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b0550_row15_col0" class="data row15 col0" >me</td>
#       <td id="T_b0550_row15_col1" class="data row15 col1" >3109</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b0550_row16_col0" class="data row16 col0" >that</td>
#       <td id="T_b0550_row16_col1" class="data row16 col1" >3063</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b0550_row17_col0" class="data row17 col0" >so</td>
#       <td id="T_b0550_row17_col1" class="data row17 col1" >3033</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b0550_row18_col0" class="data row18 col0" >with</td>
#       <td id="T_b0550_row18_col1" class="data row18 col1" >2838</td>
#     </tr>
#     <tr>
#       <th id="T_b0550_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b0550_row19_col0" class="data row19 col0" >be</td>
#       <td id="T_b0550_row19_col1" class="data row19 col1" >2776</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Print most common words, ignoring stop words.

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 def remove_stopword(x):
#       2     return [y for y in x if y not in stopwords.words('english')]
# ----> 3 df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 3, in <lambda>(x)
#       1 def remove_stopword(x):
#       2     return [y for y in x if y not in stopwords.words('english')]
# ----> 3 df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))
#
# Cell In[11], line 2, in remove_stopword(x)
#       1 def remove_stopword(x):
# ----> 2     return [y for y in x if y not in stopwords.words('english')]
#
# Cell In[11], line 2, in <listcomp>(.0)
#       1 def remove_stopword(x):
# ----> 2     return [y for y in x if y not in stopwords.words('english')]
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\api.py:218, in CorpusReader.raw(self, fileids)
#     216 contents = []
#     217 for f in fileids:
# --> 218     with self.open(f) as fp:
#     219         contents.append(fp.read())
#     220 return concat(contents)
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\api.py:231, in CorpusReader.open(self, file)
#     223 """
#     224 Return an open stream that can be used to read the given file.
#     225 If the file's encoding is not None, then the stream will
#    (...)
#     228 :param file: The file identifier of the file to read.
#     229 """
#     230 encoding = self.encoding(file)
# --> 231 stream = self._root.join(file).open(encoding)
#     232 return stream
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:334, in FileSystemPathPointer.join(self, fileid)
#     332 def join(self, fileid):
#     333     _path = os.path.join(self._path, fileid)
# --> 334     return FileSystemPathPointer(_path)
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\compat.py:41, in py3_data.<locals>._decorator(*args, **kwargs)
#      39 def _decorator(*args, **kwargs):
#      40     args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41     return init_func(*args, **kwargs)
#
# File c:\Users\Dhruv Agarwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:311, in FileSystemPathPointer.__init__(self, _path)
#     304 """
#     305 Create a new path pointer for the given absolute path.
#     306
#     307 :raise IOError: If the given path does not exist.
#     308 """
#     310 _path = os.path.abspath(_path)
# --> 311 if not os.path.exists(_path):
#     312     raise OSError("No such file or directory: %r" % _path)
#     313 self._path = _path
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %%
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(100))
temp = temp.iloc[1:,:]
temp.columns = ['content','temp_list']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_ce6fa_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_ce6fa_row1_col1 {
#   background-color: #470f84;
#   color: #f1f1f1;
# }
# #T_ce6fa_row2_col1 {
#   background-color: #6e5aa8;
#   color: #f1f1f1;
# }
# #T_ce6fa_row3_col1 {
#   background-color: #9390c3;
#   color: #f1f1f1;
# }
# #T_ce6fa_row4_col1 {
#   background-color: #9c98c7;
#   color: #f1f1f1;
# }
# #T_ce6fa_row5_col1 {
#   background-color: #a6a3cd;
#   color: #f1f1f1;
# }
# #T_ce6fa_row6_col1 {
#   background-color: #b4b4d7;
#   color: #000000;
# }
# #T_ce6fa_row7_col1 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_ce6fa_row8_col1 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_ce6fa_row9_col1 {
#   background-color: #bebedd;
#   color: #000000;
# }
# #T_ce6fa_row10_col1 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_ce6fa_row11_col1 {
#   background-color: #cdcde4;
#   color: #000000;
# }
# #T_ce6fa_row12_col1 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_ce6fa_row13_col1 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_ce6fa_row14_col1 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_ce6fa_row15_col1 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_ce6fa_row16_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_ce6fa_row17_col1, #T_ce6fa_row18_col1 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_ce6fa_row19_col1 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_ce6fa_row20_col1, #T_ce6fa_row21_col1 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_ce6fa_row22_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_ce6fa_row23_col1 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_ce6fa_row24_col1 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_ce6fa_row25_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_ce6fa_row26_col1, #T_ce6fa_row27_col1 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_ce6fa_row28_col1, #T_ce6fa_row29_col1, #T_ce6fa_row30_col1 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_ce6fa_row31_col1, #T_ce6fa_row32_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_ce6fa_row33_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_ce6fa_row34_col1, #T_ce6fa_row35_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_ce6fa_row36_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_ce6fa_row37_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_ce6fa_row38_col1, #T_ce6fa_row39_col1 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_ce6fa_row40_col1, #T_ce6fa_row41_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_ce6fa_row42_col1, #T_ce6fa_row43_col1 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_ce6fa_row44_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_ce6fa_row45_col1, #T_ce6fa_row46_col1 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_ce6fa_row47_col1, #T_ce6fa_row48_col1, #T_ce6fa_row49_col1, #T_ce6fa_row50_col1, #T_ce6fa_row51_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_ce6fa_row52_col1, #T_ce6fa_row53_col1, #T_ce6fa_row54_col1, #T_ce6fa_row55_col1, #T_ce6fa_row56_col1, #T_ce6fa_row57_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_ce6fa_row58_col1 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_ce6fa_row59_col1, #T_ce6fa_row60_col1, #T_ce6fa_row61_col1, #T_ce6fa_row62_col1, #T_ce6fa_row63_col1, #T_ce6fa_row64_col1, #T_ce6fa_row65_col1, #T_ce6fa_row66_col1, #T_ce6fa_row67_col1, #T_ce6fa_row68_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_ce6fa_row69_col1, #T_ce6fa_row70_col1, #T_ce6fa_row71_col1, #T_ce6fa_row72_col1, #T_ce6fa_row73_col1, #T_ce6fa_row74_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_ce6fa_row75_col1, #T_ce6fa_row76_col1, #T_ce6fa_row77_col1, #T_ce6fa_row78_col1, #T_ce6fa_row79_col1, #T_ce6fa_row80_col1, #T_ce6fa_row81_col1, #T_ce6fa_row82_col1, #T_ce6fa_row83_col1, #T_ce6fa_row84_col1, #T_ce6fa_row85_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_ce6fa_row86_col1, #T_ce6fa_row87_col1, #T_ce6fa_row88_col1, #T_ce6fa_row89_col1, #T_ce6fa_row90_col1, #T_ce6fa_row91_col1, #T_ce6fa_row92_col1, #T_ce6fa_row93_col1, #T_ce6fa_row94_col1, #T_ce6fa_row95_col1, #T_ce6fa_row96_col1, #T_ce6fa_row97_col1, #T_ce6fa_row98_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_ce6fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce6fa_level0_col0" class="col_heading level0 col0" >content</th>
#       <th id="T_ce6fa_level0_col1" class="col_heading level0 col1" >temp_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce6fa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ce6fa_row0_col0" class="data row0 col0" >I</td>
#       <td id="T_ce6fa_row0_col1" class="data row0 col1" >12635</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ce6fa_row1_col0" class="data row1 col0" >the</td>
#       <td id="T_ce6fa_row1_col1" class="data row1 col1" >12052</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ce6fa_row2_col0" class="data row2 col0" >a</td>
#       <td id="T_ce6fa_row2_col1" class="data row2 col1" >9352</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ce6fa_row3_col0" class="data row3 col0" >my</td>
#       <td id="T_ce6fa_row3_col1" class="data row3 col1" >7160</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ce6fa_row4_col0" class="data row4 col0" >and</td>
#       <td id="T_ce6fa_row4_col1" class="data row4 col1" >6750</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ce6fa_row5_col0" class="data row5 col0" >i</td>
#       <td id="T_ce6fa_row5_col1" class="data row5 col1" >6257</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ce6fa_row6_col0" class="data row6 col0" >you</td>
#       <td id="T_ce6fa_row6_col1" class="data row6 col1" >5535</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ce6fa_row7_col0" class="data row7 col0" >is</td>
#       <td id="T_ce6fa_row7_col1" class="data row7 col1" >5254</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_ce6fa_row8_col0" class="data row8 col0" >for</td>
#       <td id="T_ce6fa_row8_col1" class="data row8 col1" >5146</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_ce6fa_row9_col0" class="data row9 col0" >in</td>
#       <td id="T_ce6fa_row9_col1" class="data row9 col1" >5053</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_ce6fa_row10_col0" class="data row10 col0" >of</td>
#       <td id="T_ce6fa_row10_col1" class="data row10 col1" >4419</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_ce6fa_row11_col0" class="data row11 col0" >it</td>
#       <td id="T_ce6fa_row11_col1" class="data row11 col1" >4333</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_ce6fa_row12_col0" class="data row12 col0" >on</td>
#       <td id="T_ce6fa_row12_col1" class="data row12 col1" >3828</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_ce6fa_row13_col0" class="data row13 col0" >have</td>
#       <td id="T_ce6fa_row13_col1" class="data row13 col1" >3430</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_ce6fa_row14_col0" class="data row14 col0" >me</td>
#       <td id="T_ce6fa_row14_col1" class="data row14 col1" >3109</td>
#     </tr>
#     <tr>
#       <th id="T_ce6fa_level0_

# %% [markdown]
# Print table just for sentiment 'empty'.

# %%
df[df['sentiment']=='empty']
# Out:
#          tweet_id sentiment  \
# 0      1956967341     empty
# 44     1956978276     empty
# 52     1956979917     empty
# 141    1957000336     empty
# 180    1957007357     empty
# ...           ...       ...
# 39702  1753868848     empty
# 39742  1753870123     empty
# 39749  1753870555     empty
# 39845  1753886183     empty
# 39975  1753904682     empty
#
#                                                  content  \
# 0      @tiffanylue i know  i was listenin to bad habi...
# 44     @creyes middle school and elem. High schools w...
# 52               @djmicdamn hey yu lil fucker i textd yu
# 141    @softtouchme just answered you- never learned ...
# 180        Have a headache  I'm going to bed. Goodnight!
# ...                                                  ...
# 39702  Here we go again, back to work. Happy Mothers ...
# 39742  @PhilippaJane the &quot;no pants&quot; idea co...
# 39749                                  @sloanyxxx Thanks
# 39845                   @xxxRobyn Yeah *fingers crossed*
# 39975    @lexia Or even listen to Susan's green policies
#
#                                                temp_list
# 0      [@tiffanylue, i, know, i, was, listenin, to, b...
# 44     [@creyes, middle, school, and, elem., High, sc...
# 52      [@djmicdamn, hey, yu, lil, fucker, i, textd, yu]
# 141    [@softtouchme, just, answered, you-, never, le...
# 180    [Have, a, headache, I'm, going, to, bed., Good...
# ...                                                  ...
# 39702  [Here, we, go, again,, back, to, work., Happy,...
# 39742  [@PhilippaJane, the, &quot;no, pants&quot;, id...
# 39749                               [@sloanyxxx, Thanks]
# 39845              [@xxxRobyn, Yeah, *fingers, crossed*]
# 39975  [@lexia, Or, even, listen, to, Susan's, green,...
#
# [827 rows x 4 columns]

# %% [markdown]
# Get general info about data frame.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   content    40000 non-null  object
#  3   temp_list  40000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# Describes the numerics.

# %%
print(df.describe())
# Out:
#            tweet_id
# count  4.000000e+04
# mean   1.845184e+09
# std    1.188579e+08
# min    1.693956e+09
# 25%    1.751431e+09
# 50%    1.855443e+09
# 75%    1.962781e+09
# max    1.966441e+09

# %% [markdown]
# Distribution of sentiments.

# %%
sns.countplot(x='sentiment', data=df)
plt.title('Distribution of Sentiments')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Content length by sentiment.

# %%
df['content_length'] = df['content'].apply(len)
sns.boxplot(x='sentiment', y='content_length', data=df)
plt.title('Content Length by Sentiment')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Word cloud of most common words.

# %%
specific_sentiments = df[df['sentiment'].isin(['sadness', 'worry', 'hate', 'fun'])]
specific_sentiments = specific_sentiments.copy()

# %%
all_text = ' '.join(df['content'])
words = all_text.split()
word_freq = Counter(words)
common_words = word_freq.most_common(20)
plt.figure(figsize=(10, 8))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(common_words))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Most Common Words')
plt.axis('off')
plt.show()

# %% [markdown]
# Word cloud for 4 most dominant sentiments.

# %%
print(df['sentiment'].unique())
specific_sentiments = df[df['sentiment'].isin(['sadness', 'worry', 'hate', 'fun'])]
all_text_specific = ' '.join(specific_sentiments['content'])
words_specific = all_text_specific.split()
word_freq_specific = Counter(words_specific)
common_words_specific = word_freq_specific.most_common(20)
# Out:
# ['empty' 'sadness' 'enthusiasm' 'neutral' 'worry' 'surprise' 'love' 'fun'
#  'hate' 'happiness' 'boredom' 'relief' 'anger']

# %%
wordcloud_specific = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(common_words_specific))
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud_specific, interpolation='bilinear')
plt.title('Most Common Words in Specific Sentiments')
plt.axis('off')
plt.show()

# %% [markdown]
# Content length comparison for similar sentiments.

# %%
specific_sentiments = df[df['sentiment'].isin(['sadness', 'worry', 'hate', 'love', 'fun', 'neutral'])]

# %%
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 3, 1)
sns.scatterplot(x='sentiment', y='content_length', data=specific_sentiments[specific_sentiments['sentiment'].isin(['sadness', 'worry'])])
plt.title('Sadness vs Worry')
# Out:
# Text(0.5, 1.0, 'Sadness vs Worry')

# %%
plt.subplot(1, 3, 2)
sns.scatterplot(x='sentiment', y='content_length', data=specific_sentiments[specific_sentiments['sentiment'].isin(['hate', 'love'])])
plt.title('Hate vs Love')
# Out:
# Text(0.5, 1.0, 'Hate vs Love')

# %%
plt.subplot(1, 3, 3)
sns.scatterplot(x='sentiment', y='content_length', data=specific_sentiments[specific_sentiments['sentiment'].isin(['fun', 'neutral'])])
plt.title('Fun vs Neutral')
# Out:
# Text(0.5, 1.0, 'Fun vs Neutral')

# %%
plt.tight_layout()
plt.show()
